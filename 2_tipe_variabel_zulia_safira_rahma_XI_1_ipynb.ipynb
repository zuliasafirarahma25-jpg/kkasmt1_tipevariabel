# %% [markdown]
# <a href="https://colab.research.google.com/github/zuliasafirarahma25-jpg/kkasmt1_tipevariabel/blob/main/2_tipe_variabel_zulia_safira_rahma_XI_1_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nama = zulia safira rahma
#
# kelas = XI-1
#
# no absen =36

# %% [markdown]
# #konsep dasar

# %%
email_user_1 = "zuliasafirarahma.25@gmail.com"
print(email_user_1)
# Out:
# zuliasafirarahma.25@gmail.com

# %%
sabun_lifebuoy =15000
print(sabun_lifebuoy)
# Out:
# 15000

# %%
print(sabun_lifebuoy*5)
# Out:
# 75000

# %% [markdown]
# #peraturan penulisan variabel

# %%
#penulisan variabel hanya boleh menggunakan angka,huruf,underscore
#tidak boleh menggunakan spasi
nama siswa =safira
print(nama siswa)
# Out:
#   File "/tmp/ipython-input-2334166989.py", line 3
#     nama siswa =safira
#          ^
# SyntaxError: invalid syntax

# %%
#tidak boleh diawali dengan angka
1_nama siswa = safira
print(1_nama siswa)
# Out:
#   File "/tmp/ipython-input-2057245886.py", line 2
#     1nama siswa = safira
#     ^
# SyntaxError: invalid decimal literal

# %%
#penulisan variabel itu case sensitif capslock
nama_siswa_1= safira
print(Nama_siwa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4287123822.py in <cell line: 0>()
#       1 #penulisan variabel itu case sensitif capslock
# ----> 2 nama_siswa_1= safira
#       3 print(Nama_siwa_1)
#
# NameError: name 'safira' is not defined

# %%
dilarang menggunakan kata kunci python
prin = "safira"
print(prin)
# Out:
#   File "/tmp/ipython-input-434476040.py", line 1
#     dilarang menggunakan kata kunci python
#              ^
# SyntaxError: invalid syntax

# %%
# Tidak boleh pakai kata kunci python, if, for, class, print, dll
# Kalau error akibat membuat nama variabel dengan kata kunci print, maka, harus disconnect dulu
# print = "Devin"

# print(print)

# %%
end = "Naufal"

print(end)
# Out:
# Naufal

# %%
#Tidak Deskriptif
_ = "Favian" # Bisa, tapi tidak jelas/tidak deskriptif

print(_)

#Seharusnya, yang deskriptif:

nama_pelanggan = "Faviana"
print(nama_pelanggan)
# Out:
# Favian
# Faviana

# %% [markdown]
# #assignment

# %% [markdown]
# ##single assignement

# %%
nama_siswa_2 = "Dhapne"
nama_siswa_3 = "Farel"

print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Dhapne
# Farel

# %% [markdown]
# ##multiple assignment

# %%
nama_siswa_4, nama_siswa_5 = "Sada", "Selo"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# Sada
# Selo

# %% [markdown]
# ##Chain Assignment

# %%
nilai_afa = nilai_favian = 100

print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# ##Perubahan Nilai Variabel

# %%
nilai_afa = 95
print(nilai_afa)
# Out:
# 95

# %% [markdown]
# #cara penggunaan operator

# %%
#Tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#Simpan operand ke dalam variabel
harga_kojek = 6000
banyak_porsi = 3

print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#Simpan hasil operasi ke dalam variabel
harga_total_kojek = 3000*3

print(harga_total_kojek)
# Out:
# 9000

# %%
#Simpan nilai operand dan hasil operasi ke dalam variabel
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000
uang_kembalian = uang_yang_diterima - harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %% [markdown]
# #jenis-jenis operator

# %% [markdown]
# ##operator aritmatika

# %%
uang_shinta = 200000
uang_favian = 500000
uang_total = uang_shinta + uang_favian

print(uang_total)
# Out:
# 700000

# %%
uang_customer = 300000
total_belanja = 250000
uang_kembalian = uang_customer - total_belanja

print(uang_kembalian)
# Out:
# 50000

# %%
harga_susu_kotak = 5000
jumlah_susu_kotak = 3
harga_susu_total = harga_susu_kotak*jumlah_susu_kotak

print(harga_susu_total)
# Out:
# 15000

# %%
banyak_roti = 20
jumlah_tamu = 7

roti_setiap_tamu = banyak_roti/jumlah_tamu

print(roti_setiap_tamu)
# Out:
# 2.857142857142857

# %%
banyak_roti = 20
jumlah_tamu = 7

roti_setiap_tamu = banyak_roti//jumlah_tamu

print(roti_setiap_tamu)
# Out:
# 2

# %%
banyak_roti = 20
jumlah_tamu = 7

sisa_roti = banyak_roti%jumlah_tamu

print(sisa_roti)
# Out:
# 6

# %%
sisi_persegi = 5
luas_persegi = sisi_persegi**2

print(luas_persegi)
# Out:
# 25

# %%
luas_persegi = 36
sisi_persegi = luas_persegi**0.5

print(sisi_persegi)
# Out:
# 6.0

# %% [markdown]
# #tipe variabel

# %%
usia = 16

type(usia)
# Out:
# int

# %%
berat_telur = 2.5

type(berat_telur)
# Out:
# float

# %%
nama = "safira"

type(nama)
# Out:
# str

# %%
remidi = False

type(remidi)
# Out:
# bool

# %%
remidi = True

type(remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5

type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8

type(koordinat_titik)
# Out:
# int

# %% [markdown]
# #input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)

# %%
input()
# Out:
# 5
# '5'

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
panjang_1 = int(input("masukan panjang persegi: "))
# Out:
# masukan panjang persegi: 10

# %%
panjang_2  = int(input("masukan panjang persegi: "))
lebar_2 = int(input("masukan lebar balok: "))

luas_2 = panjang_2*lebar_2

print(f"luas persegi panjang adalah {luas_2} cm^2")
# Out:
# masukan panjang persegi: 20
# masukan lebar balok: 5
# luas persegi panjang adalah 100 cm^2

# %% [markdown]
# ##tugas

# %%
panjang = int(input("masukan panjang balok: "))
lebar = int(input("masukan lebar balok: "))
tinggi = int(input("masukan tinggi balok: "))

volume = panjang*lebar*tinggi
print(f" volume balok adalah {volume} cm^3")
# Out:
# masukan panjang balok: 10
# masukan lebar balok: 5
# masukan tinggi balok: 4
#  volume balok adalah 200 cm^3

# %% [markdown]
# #konversi tipe data

# %%
a = 3

print(a)
type(a)
# Out:
# 3
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 3.0
# float

# %%
a =  str ( a )
print( a )
type( a )
# Out:
# 3.0
# str

# %%
a = bool (a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = "cicak"
print( b )

b = bool
print( b )
# Out:
# cicak
# <class 'bool'>

# %%
c = ""
print(c)

c = bool( c )
print(c)
# Out:
# False

# %%
d = False
print(d)
type(d)
# Out:
# False
# bool

# %%
e = "false"
print(e)
type(e)
# Out:
# false
# str

# %% [markdown]
# #operator perbandingan

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8 == 5)
# Out:
# False

# %%
print(8==8)
# Out:
# True

# %%
print(1!=1)
# Out:
# False

# %%
a= 10
b= 20
c= 30

print(a<c)
# Out:
# True

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka = 75
kkm_kka = 80

print(nilai_kka >kkm_kka)
# Out:
# False

# %% [markdown]
# #operator logika

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5>6)
# Out:
# True

# %%
print(not (8>7 or 5>6))
# Out:
# False

# %%
print(not (8>=9 or 9!=8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165

print(125 >=iq_min and 170 >= tinggi_min)
# Out:
# True

# %%
iq_safira = 125
tinggi_safira =170

print(iq_safira >= iq_min and tinggi_safira >= tinggi_min)
# Out:
# True

# %%
tinggi_badan_min = 160
berat_badan_min = 50
umur_max = 25

tinggi_farel = 170
berat_badan_farel =55
umur_farel =23

print(tinggi_farel >= tinggi_badan_min and berat_badan_farel >= tinggi_badan_min and umur_farel <= umur_min)
# Out:
# False
